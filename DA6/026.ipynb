# %%
import pandas as pd
import seaborn as sns

# # 调色板palette设为绿色作一个映射，背景颜色的深浅表示数据的大小
# color_map = sns.light_palette('green', as_cmap=True)

students = pd.read_excel('./Students.xlsx', index_col='ID')
# students.style.background_gradient(color_map, subset=['Test_1','Test_2','Test_3'])
students.style.bar(color='orange', subset=['Test_1','Test_2','Test_3'])
# Out:
# <style  type="text/css" >
#     #T_18b29cf6_2a19_11e9_a1e6_acde48001122row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 26.9%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 22.7%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 8.2%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 84.6%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 12.5%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 18.4%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 43.6%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 15.9%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 36.7%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 79.5%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 28.4%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 85.7%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 44.9%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 100.0%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 87.8%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 84.6%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 1.1%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row5_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 91.0%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row6_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 8.2%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row7_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 98.9%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 4.1%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 69.2%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 84.1%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 26.5%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 10.3%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 98.9%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 100.0%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 19.2%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 81.8%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row10_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 71.4%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 3.8%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row11_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 42.0%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row11_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 34.7%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 32.1%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row12_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 58.0%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row12_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 81.6%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 55.1%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row13_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 17.0%, transparent 0%);
#         }    #T_18b29cf6_2a19_11e9_a1e6_acde48001122row13_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 12.2%, transparent 0%);
#         }    #T_18
